# %%
import requests

def get_product_details(product_id):
    url = f"https://dev.shopalyst.com/shopalyst-service/v1/products/{product_id}"
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching product details: {e}")
        return None

    try:
        data = response.json()
        # Debug prints for structure inspection
        print("Raw API response:")
        print(data)
        print("Response keys:", data.keys())
    except ValueError:
        print("Error parsing JSON response")
        return None

    return data

def print_sku_details(data):
    if data is None:
        print("No data to process.")
        return

    # For this API, SKU details are provided under "skuSet"
    sku_set = data.get("skuSet")
    if not sku_set:
        print("No SKUs found for the given product.")
        return

    # Build a mapping from attribute id to attribute details from "attributeValues"
    attribute_values = data.get("attributeValues", [])
    attr_map = {attr["id"]: attr for attr in attribute_values}

    for index, sku in enumerate(sku_set, start=1):
        sku_id = sku.get("skuId", "N/A")
        offer_price = sku.get("offerPrice", "N/A")
        # Retrieve the attribute id from the sku attributes (assuming key "1")
        attr_id = sku.get("attributes", {}).get("1", "N/A")
        # Look up attribute details using the attribute id
        attr_detail = attr_map.get(attr_id, {})
        # For the shade, we use the attribute's "value" field
        shade = attr_detail.get("value", "N/A")
        # For the SKU title, we use the attribute's "title" field
        sku_title = attr_detail.get("title", "N/A")
        print("--------------------------")
        print(f"Product {index}")
        print(f"skuId : {sku_id}")
        print(f"shade : {shade}")
        print(f"offerPrice : {offer_price}")
        print(f"title : {sku_title}")
    print("--------------------------")

def main():
    product_id = input("Enter the product id: ").strip()
    if not product_id:
        print("Product id is required.")
        return

    data = get_product_details(product_id)
    if not data:
        return

    print_sku_details(data)

if __name__ == "__main__":
    main()
# Out:
# Enter the product id: 12C7BFC3752D4209
# Raw API response:
# {'active': False, 'altUrl': '', 'articleType': 'Lip Stain', 'attributeNames': [{'id': '1', 'name': 'color', 'rank': '1'}], 'attributeValues': [{'id': 'M423', 'value': 'M423', 'rank': '1', 'images': '["https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23601_h.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23601_h_2_.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23601_s1.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/h/u/hul_certifcate-page-001_81_12.jpg"]', 'swatchImage': 'https://images-static.nykaa.com/media/icons/lakm_enrisatinm423.jpg', 'title': 'Lakme Enrich Satin Lipstick - M423', 'videos': '[]'}, {'id': 'M454', 'value': 'M454', 'rank': '1', 'images': '["https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23604_h.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23604_h_2_.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23604_s1.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/h/u/hul_certifcate-page-001_75_34.jpg"]', 'swatchImage': 'https://images-static.nykaa.com/media/icons/lakm_enrisatinm454.jpg', 'title': 'Lakme Enrich Satin Lipstick - M454', 'videos': '[]'}, {'id': 'M455', 'value': 'M455', 'rank': '1', 'images': '["https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23605_h.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23605_h_2_.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23605_s1.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/h/u/hul_certifcate-page-001_74_53.jpg"]', 'swatchImage': 'https://images-static.nykaa.com/media/icons/lakm_enrisatinm455.jpg', 'title': 'Lakme Enrich Satin Lipstick - M455', 'videos': '[]'}, {'id': 'M422', 'value': 'M422', 'rank': '1', 'images': '["https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23600_h.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23600_h_2_.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23600_s1.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/h/u/hul_certifcate-page-001_82_10.jpg"]', 'swatchImage': 'https://images-static.nykaa.com/media/icons/lakm_enrisatinm422.jpg', 'title': 'Lakme Enrich Satin Lipstick - M422', 'videos': '[]'}, {'id': 'P128', 'value': 'P128', 'rank': '1', 'images': '["https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23579_h.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23579_h_2_.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23579_s1.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/h/u/hul_certifcate-page-001_73_57.jpg"]', 'swatchImage': 'https://images-static.nykaa.com/media/icons/lakm_enrisatinp128.jpg', 'title': 'Lakme Enrich Satin Lipstick - P128', 'videos': '[]'}, {'id': 'P147', 'value': 'P147', 'rank': '1', 'images': '["https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23584_h.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23584_h_2_.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/2/3/23584_s1.jpg", "https://images-static.nykaa.com/media/catalog/product/tr:h-800,w-800,cm-pad_resize/h/u/hul_certifcate-page-001_73_58.jpg"]', 'swatchImage': 'https://images-static.nykaa.com/media/icons/lakm_enrisatinp147.jpg', 'title': 'Lakme Enrich Satin Lipstick - P147', 'videos': '[]'}, {'id' ...
# Response keys: dict_keys(['active', 'altUrl', 'articleType', 'attributeNames', 'attributeValues', 'avgRating', 'brand', 'brandName', 'category', 'categoryRank', 'changed', 'creationDate', 'description', 'discount', 'division', 'extAttributes', 'gender', 'imageUrl', 'images', 'lastChangedTime', 'lastModifiedDate', 'merchant', 'merchantDivision', 'newArrival', 'normBrand', 'normalizedArticleType', 'normalizedCategory', 'normalizedSubCategory', 'offerPrice', 'ondcProduct', 'productId', 'productType', 'productUrl', 'ratingScore', 'ratingsCount', 'reviewsCount', 'salePrice', 'secondaryColor', 'seoTitle', 'skuSet', 'styleNote', 'subCategory', 'title', 'trendingRank', 'trueDiscount', 'vendor', 'videos'])
# --------------------------
# Product 1
# skuId : 24061
# shade : M423
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - M423
# --------------------------
# Product 2
# skuId : 24064
# shade : M454
# offerPrice : 270.0
# title : Lakme Enrich Satin Lipstick - M454
# --------------------------
# Product 3
# skuId : 24065
# shade : M455
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - M455
# --------------------------
# Product 4
# skuId : 24060
# shade : M422
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - M422
# --------------------------
# Product 5
# skuId : 24070
# shade : P128
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - P128
# --------------------------
# Product 6
# skuId : 24075
# shade : P147
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - P147
# --------------------------
# Product 7
# skuId : 24080
# shade : P158
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - P158
# --------------------------
# Product 8
# skuId : 24084
# shade : R353
# offerPrice : 270.0
# title : Lakme Enrich Satin Lipstick - R353
# --------------------------
# Product 9
# skuId : 24087
# shade : R354
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - R354
# --------------------------
# Product 10
# skuId : 24062
# shade : M427
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - M427
# --------------------------
# Product 11
# skuId : 24077
# shade : P149
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - P149
# --------------------------
# Product 12
# skuId : 24078
# shade : P152
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - P152
# --------------------------
# Product 13
# skuId : 24079
# shade : P154
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - P154
# --------------------------
# Product 14
# skuId : 24083
# shade : R352
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - R352
# --------------------------
# Product 15
# skuId : 24088
# shade : R356
# offerPrice : 270.0
# title : Lakme Enrich Satin Lipstick - R356
# --------------------------
# Product 16
# skuId : 24089
# shade : R357
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - R357
# --------------------------
# Product 17
# skuId : 24090
# shade : R358
# offerPrice : 270.0
# title : Lakme Enrich Satin Lipstick - R358
# --------------------------
# Product 18
# skuId : 24091
# shade : R359
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - R359
# --------------------------
# Product 19
# skuId : 24092
# shade : R360
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - R360
# --------------------------
# Product 20
# skuId : 24068
# shade : N651
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - N651
# --------------------------
# Product 21
# skuId : 24073
# shade : P135
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - P135
# --------------------------
# Product 22
# skuId : 27619
# shade : P165
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - P165
# --------------------------
# Product 23
# skuId : 24074
# shade : P140
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - P140
# --------------------------
# Product 24
# skuId : 24076
# shade : P148
# offerPrice : 285.0
# title : Lakme Enrich Satin Lipstick - P148
# --------------------------
